# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.8/872.8 kB 23.7 MB/s eta 0:00:00
# ...

# %%
# !cp -r /content/drive/MyDrive/levelDataset/ /content/

# %%
# !ls /content/levelDataset/train/labels
# Out:
# bat_10_336_png.rf.d6cc7cac577aac84793fd64171b664ca.txt
# bat_10_339_png.rf.cfcc5ba126a9fb160875f2ec16d03b40.txt
# bat_10_340_png.rf.75936c304c4f080dfb9663b594e949b7.txt
# bat_10_341_png.rf.98720ad21e69eb140ab7e228a08940e8.txt
# bat_10_346_png.rf.04b6f54529ac874a78e069958c459ab2.txt
# bat_10_347_png.rf.2ecf6ebcef68b2e37917930aaa5a254d.txt
# bat_10_348_png.rf.b7b69559f6dc35991bbf94a51bc66027.txt
# bat_10_349_png.rf.13816bc8e0901aefcf3f77b07fd5e75f.txt
# bat_10_351_png.rf.ea435e64157b760cbb1a652c685d6044.txt
# bat_10_353_png.rf.24c5b85070110ce5da43f64ffb3be4ad.txt
# bat_10_355_png.rf.292e6ffb28e1735b695fc806fa0d7cb5.txt
# bat_10_357_png.rf.fa053f7c07c99edccec503deec9446c5.txt
# bat_10_358_png.rf.132f48ee5734a8f2a9dbe8fe178bf333.txt
# bat_10_368_png.rf.81c0dbeab04bbfbe7501bc5361ea1afd.txt
# bat_10_372_png.rf.29e8818210e442f9fd243b395edea87d.txt
# bat_10_373_png.rf.9cff7a9532cbc270465ce204bd332a1d.txt
# bat_10_374_png.rf.628d873877a240f322b8fd1072ea20ba.txt
# ...

# %%
# %cd levelDataset
# Out:
# /content/levelDataset

# %%
# !pwd
# Out:
# /content/levelDataset

# %%
# !yolo task=segment mode=train epochs=100 data=/content/levelDataset/data.yaml model=yolov8m-seg.pt imgsz=640 batch=8
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mkdir /content/drive/MyDrive/NewLevelDataset
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/NewLevelDataset’: File exists

# %%
# !cp -r /content/levelDataset/ /content/drive/MyDrive/NewLevelDataset/
